# %%
import os, json, re
import spacy

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Define input & output paths
data_path = "./data/judgement/"              # folder containing your .txt files
output_path = "./data/split_prepared_custom"
os.makedirs(output_path, exist_ok=True)
